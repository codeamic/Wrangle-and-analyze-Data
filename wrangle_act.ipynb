# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
#import necessarry python libraries required to carry out data wrangling
import pandas as pd
import requests
import json
import os

# %%
#Load the first dataset for twitter-archive-enhanced and print the first values
df1 = pd.read_csv('twitter-archive-enhanced.csv')
df1.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
#Make directory if it doesn't already exist
folder_name = 'image_predictions'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %%
#Do a get request on a web sever given a particular url. Downloading web content programatically
url ='https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

# %%
 #Write the respond content to the folder i creted above
with open(os.path.join(folder_name, url.split('/')[-1]), mode = 'wb') as file:
    file.write(response.content)

# %%
#read the data from the folder we created and downloaded
df2 = pd.read_csv('image_predictions/image-predictions.tsv', sep="\t")
df2.head(50)
# Out:
#               tweet_id                                          jpg_url  \
# 0   666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1   666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2   666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3   666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4   666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5   666050758794694657  https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6   666051853826850816  https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7   666055525042405380  https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8   666057090499244032  https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9   666058600524156928  https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10  666063827256086533  https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# 11  666071193221509120  https://pbs.twimg.com/media/CT5cN_3WEAAlOoZ.jpg
# ...

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
# Code from udacity classroom

import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = df1.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)

# %%
#Create a list, convert data gotten from twitter api and pass particular values in the list. then use the list to create a dataframe
df3_list = []
count = 0
file_name = 'tweet-json.txt'
with open(file_name, encoding='utf-8') as file:
    for file_line in file:
        count +=1
        json_file = file.readline()
        data = (json.loads(file_line))
        tweet_id = data['id']
        retweet_count = data['retweet_count']
        favorite_count = data['favorite_count']
        df3_list.append({'tweet_id': tweet_id,
                                 'retweet_count':retweet_count,
                                 'favorite_count':favorite_count})
        df3 = pd.DataFrame(df3_list, columns = ['tweet_id', 'retweet_count', 'favorite_count'])

# %%
#view the data  in the df3 data set
df3
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           8853           39467
# 1     891815181378084864           4328           25461
# 2     891327558926688256           9774           41048
# 3     890971913173991426           2158           12041
# 4     890609185150312448           4429           28226
# ...                  ...            ...             ...
# 1172  666058600524156928             61             115
# 1173  666055525042405380            261             448
# 1174  666050758794694657             60             136
# 1175  666044226329800704            147             311
# 1176  666029285002620928             48             132
#
# [1177 rows x 3 columns]

# %% [markdown]
# ## Assessing Data
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment
# programmatic assessement to assess the data.
#
# **Note:** pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %% [markdown]
# ### Twitter archive data

# %%
#get the fist 50 data in dataset for virsual aassessment 
df1.head(50)
# Out:
#               tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0   892420643555336193                    NaN                  NaN
# 1   892177421306343426                    NaN                  NaN
# 2   891815181378084864                    NaN                  NaN
# 3   891689557279858688                    NaN                  NaN
# 4   891327558926688256                    NaN                  NaN
# 5   891087950875897856                    NaN                  NaN
# 6   890971913173991426                    NaN                  NaN
# 7   890729181411237888                    NaN                  NaN
# 8   890609185150312448                    NaN                  NaN
# 9   890240255349198849                    NaN                  NaN
# 10  890006608113172480                    NaN                  NaN
# 11  889880896479866881                    NaN                  NaN
# 12  889665388333682689                    NaN                  NaN
# ...

# %%
#Check if df1 contains null values
df1.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
#Check if there is any repetition in tweet_id
df1['tweet_id'].nunique(), df1.shape
# Out:
# (2356, (2356, 17))

# %%
check_denominator = df1.query('rating_denominator != 10')
check_denominator = check_denominator['rating_denominator']
check_denominator.shape
# Out:
# (23,)

# %%
#get detail description of the dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
#get statistical description of the dataset
df1.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
#get a list of all the column in dataset
list(df1)
# Out:
# ['tweet_id',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'timestamp',
#  'source',
#  'text',
#  'retweeted_status_id',
#  'retweeted_status_user_id',
#  'retweeted_status_timestamp',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo']

# %%
#Check if any null value exist in rating_denominator
df1_clean['rating_denominator'].isnull().values.any()
# Out:
# False

# %% [markdown]
# ###  Tweet image prediction(df2)

# %%
#get the first 50 columns of the dataset for virsual assessment
df2.head(50)
# Out:
#               tweet_id                                          jpg_url  \
# 0   666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1   666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2   666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3   666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4   666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5   666050758794694657  https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6   666051853826850816  https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7   666055525042405380  https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8   666057090499244032  https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9   666058600524156928  https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10  666063827256086533  https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# 11  666071193221509120  https://pbs.twimg.com/media/CT5cN_3WEAAlOoZ.jpg
# ...

# %%
#get the mean for the confidentiality of each prediction
df2['p1_conf'].mean(), df2['p2_conf'].mean(), df2['p3_conf'].mean()
# Out:
# (0.5945482636144582, 0.13458860950039184, 0.06032416861810644)

# %%
#check for duplicated values in tweet ids
df2.tweet_id.nunique(), df2.shape
# Out:
# (2075, (2075, 12))

# %%
#get detail description of the dataset
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
#Check if df2 contains null values
df2.isnull().sum()
# Out:
# 0

# %%
list(df2)
# Out:
# ['tweet_id',
#  'jpg_url',
#  'img_num',
#  'p1',
#  'p1_conf',
#  'p1_dog',
#  'p2',
#  'p2_conf',
#  'p2_dog',
#  'p3',
#  'p3_conf',
#  'p3_dog']

# %%
df2['jpg_url'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2070    False
# 2071    False
# 2072    False
# 2073    False
# 2074    False
# Name: jpg_url, Length: 2075, dtype: bool

# %% [markdown]
# ###  Twitter API(tweet.json)
# - df3

# %%
#get the first 50 columns of the dataset for virsual assessment
df3.head(50)
# Out:
#               tweet_id  retweet_count  favorite_count
# 0   892420643555336193           8853           39467
# 1   891815181378084864           4328           25461
# 2   891327558926688256           9774           41048
# 3   890971913173991426           2158           12041
# 4   890609185150312448           4429           28226
# 5   890006608113172480           7624           31166
# 6   889665388333682689           8538           38818
# 7   889531135344209921           2321           15359
# 8   888917238123831296           4709           29611
# 9   888554962724278272           3732           20290
# 10  887705289381826560           5609           30779
# 11  887473957103951883          18781           69871
# 12  887101392804085760           6167           31061
# 13  886736880519319552           3443           12306
# 14  886366144734445568           3316           21524
# 15  886258384151887873           6523           28469
# ...

# %%
df3.tail(50)
# Out:
#                 tweet_id  retweet_count  favorite_count
# 1127  667766675769573376            243             476
# 1128  667724302356258817            341             517
# 1129  667550882905632768             34               0
# 1130  667546741521195010            138             355
# 1131  667538891197542400             72             220
# 1132  667530908589760512            264             501
# 1133  667517642048163840            203             389
# 1134  667502640335572993            231             563
# 1135  667491009379606528            242             559
# 1136  667455448082227200             66             203
# 1137  667443425659232256            620             833
# 1138  667435689202614272             89             326
# 1139  667393430834667520             60             211
# 1140  667211855547486208            258             516
# 1141  667192066997374976            115             414
# 1142  667182792070062081           6618           15075
# ...

# %%
#check for duplicated values in tweet ids
df3.tweet_id.nunique(), df2.shape
# Out:
# (1177, (2075, 12))

# %%
#get detail description of the dataset
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1177 entries, 0 to 1176
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        1177 non-null   int64
#  1   retweet_count   1177 non-null   int64
#  2   favorite_count  1177 non-null   int64
# dtypes: int64(3)
# memory usage: 27.7 KB

# %%
#get statistical description of datasets
df3.describe()
# Out:
#            tweet_id  retweet_count  favorite_count
# count  1.177000e+03    1177.000000     1177.000000
# mean   7.427463e+17    3222.255735     8260.755310
# std    6.856773e+16    5106.835873    12088.982006
# min    6.660293e+17       0.000000        0.000000
# 25%    6.783997e+17     634.000000     1499.000000
# 50%    7.195514e+17    1483.000000     3705.000000
# 75%    7.993088e+17    3737.000000    10202.000000
# max    8.924206e+17   52360.000000   132810.000000

# %%
list(df3)
# Out:
# ['tweet_id', 'retweet_count', 'favorite_count']

# %%
list(df3)
# Out:
# ['tweet_id', 'retweet_count', 'favorite_count']

# %% [markdown]
# ### Quality issues
#
# #### Twitter_archive_enhanced(df1)
# 1. data in source not in a good format
# 2. missing values in retweeted_status_id
# 3. missing values in (retweeted_status_user_id,retweeted_status_timestamp)
# 4. rating_denominator should be 10 for all rows in df1
# 5. Missing values (in_reply_to_status_id, in_reply_to_user_id)
# 6. Wrong datatype for Timestamp in df1 df1 should be be converted to date
# 7. timeStamp contains multiple variables(time and date)
#
# #### Tweet image prediction(df2)
# 8. Duplicates in jpj_url
# - dog with stage of both pupper and doggo should be a puppo
# - dog with stage of both doggo and pupper be a pupper

# %% [markdown]
# ### Tidiness issues
#
# 1. tweet_json.txt(df2), df3 should be part of twitter_archive_enhanced(df1) dataframe
#
# 2. doggo, floofer, pupper and puppo are variable names and column names ate the same time

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Make copies of original pieces of data
df1_clean = df1.copy()
df2_clean = df2.copy()
df3_clean = df3.copy()

# %% [markdown]
# ### Issue #1: data in source not in a good format(df1)

# %% [markdown]
# #### Define: Get the link from html tags

# %% [markdown]
# #### Code

# %%
pattern = r'(https?:\/\/(?:www\.)?[-a-zA-Z0-9@:%._+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}[-a-zA-Z0-9()@:%_+.~#?&/=]*)'
df1_clean['source']= df1_clean["source"].str.extract(pattern, expand=True)

# %% [markdown]
# #### Test

# %%
df1_clean.head(5)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp                              source  \
# 0  2017-08-01 16:23:56 +0000  http://twitter.com/download/iphone
# 1  2017-08-01 00:17:27 +0000  http://twitter.com/download/iphone
# 2  2017-07-31 00:18:03 +0000  http://twitter.com/download/iphone
# 3  2017-07-30 15:58:51 +0000  http://twitter.com/download/iphone
# 4  2017-07-29 16:00:24 +0000  http://twitter.com/download/iphone
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# ...

# %% [markdown]
# ### Issue #2: missing values in retweeted_status_id

# %% [markdown]
# #### Define: Drop the  retweeted_status_id

# %% [markdown]
# #### Code

# %%
df1_clean = df1_clean.drop('retweeted_status_id', axis=1)

# %% [markdown]
# #### Test

# %%
df1_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp                              source  \
# 0  2017-08-01 16:23:56 +0000  http://twitter.com/download/iphone
# 1  2017-08-01 00:17:27 +0000  http://twitter.com/download/iphone
# 2  2017-07-31 00:18:03 +0000  http://twitter.com/download/iphone
# 3  2017-07-30 15:58:51 +0000  http://twitter.com/download/iphone
# 4  2017-07-29 16:00:24 +0000  http://twitter.com/download/iphone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# ...

# %% [markdown]
# ### Issue #3:  missing values in retweeted_status_user_id, retweeted_status_timestamp

# %% [markdown]
# #### Define: Drop this column

# %% [markdown]
# #### Code

# %%
df1_clean = df1_clean.drop(['retweeted_status_user_id','retweeted_status_timestamp'], axis=1)

# %% [markdown]
# #### Test

# %%
df1_clean.head(5)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp                              source  \
# 0  2017-08-01 16:23:56 +0000  http://twitter.com/download/iphone
# 1  2017-08-01 00:17:27 +0000  http://twitter.com/download/iphone
# 2  2017-07-31 00:18:03 +0000  http://twitter.com/download/iphone
# 3  2017-07-30 15:58:51 +0000  http://twitter.com/download/iphone
# 4  2017-07-29 16:00:24 +0000  http://twitter.com/download/iphone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# ...

# %% [markdown]
# ### Issue #4:  rating_denominator should be 10 for all rows in df1

# %% [markdown]
# #### Define: Assign 10 to the entire rating_denominator column

# %% [markdown]
# #### Code

# %%
df1_clean['rating_denominator'] = 10

# %% [markdown]
# #### Test

# %%
df1_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp                              source  \
# 0  2017-08-01 16:23:56 +0000  http://twitter.com/download/iphone
# 1  2017-08-01 00:17:27 +0000  http://twitter.com/download/iphone
# 2  2017-07-31 00:18:03 +0000  http://twitter.com/download/iphone
# 3  2017-07-30 15:58:51 +0000  http://twitter.com/download/iphone
# 4  2017-07-29 16:00:24 +0000  http://twitter.com/download/iphone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# ...

# %%
#check if there is any denominator not equalls to 10
df1_clean.query('rating_denominator !=10')
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ### Issue #5: Missing values (in_reply_to_status_id, in_reply_to_user_id)

# %% [markdown]
# #### Define:  Drop these columns given that they mostly contain null values and are not vital for our analysis

# %% [markdown]
# #### Code

# %%
df1_clean = df1_clean.drop(['in_reply_to_status_id','in_reply_to_user_id'], axis=1)

# %% [markdown]
# #### Test

# %%
df1_clean.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                source  \
# 0  http://twitter.com/download/iphone
# 1  http://twitter.com/download/iphone
# 2  http://twitter.com/download/iphone
# 3  http://twitter.com/download/iphone
# 4  http://twitter.com/download/iphone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# ...

# %% [markdown]
# ### Issue #6: Wrong datatype for timestamp in df1

# %% [markdown]
# #### Define: convert to datetime

# %% [markdown]
# #### Code

# %%
df1_clean['timestamp'] = pd.to_datetime(df1_clean['timestamp'])

# %% [markdown]
# #### Test

# %%
df1_clean['timestamp'].dtypes
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# ### Issue #7: timeStamp contains multiple variables(time and date)

# %% [markdown]
# #### Define: Extract date from time stamp and create a new column tweet_date and  drop timestamp

# %% [markdown]
# #### Code

# %%
df1_clean['tweet_date'] = df1_clean['timestamp'].dt.date
df1_clean = df1_clean.drop('timestamp', axis = 1)

# %% [markdown]
# #### Test

# %%
df1_clean.head()
# Out:
#              tweet_id                              source  \
# 0  892420643555336193  http://twitter.com/download/iphone
# 1  892177421306343426  http://twitter.com/download/iphone
# 2  891815181378084864  http://twitter.com/download/iphone
# 3  891689557279858688  http://twitter.com/download/iphone
# 4  891327558926688256  http://twitter.com/download/iphone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# ...

# %% [markdown]
# ### Issue #8: Duplicates in jpg_url (df2)

# %% [markdown]
# #### Define: Remove all other duplicated rows and keep just the first row

# %% [markdown]
# #### Code

# %%
df2_clean.drop_duplicates(subset="jpg_url",
                     keep='last', inplace=True)

# %% [markdown]
# #### Test

# %%
df2_clean['jpg_url'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Issue #9:doggo, floofer, pupper and puppo are variable names and column names ate the same time

# %% [markdown]
# #### Define: doggo, floofer, pupper and puppo should be converted to a single row which i will call dogs_stage

# %% [markdown]
# #### Code

# %%
df1_clean.replace(to_replace={
             'doggo':{"None":''}, 
             'floofer':{"None":''},
             'puppo':{"None":''},
             'pupper':{"None":''},
                 },inplace = True)

# %%
df1_clean.head(5)
# Out:
#              tweet_id                              source  \
# 0  892420643555336193  http://twitter.com/download/iphone
# 1  892177421306343426  http://twitter.com/download/iphone
# 2  891815181378084864  http://twitter.com/download/iphone
# 3  891689557279858688  http://twitter.com/download/iphone
# 4  891327558926688256  http://twitter.com/download/iphone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# ...

# %%
df1_clean['dog_stage'] = df1_clean.doggo+ df1_clean.floofer+df1_clean.pupper+ df1_clean.puppo

# %%
df1_clean = df1_clean.drop(['doggo','floofer', 'pupper', 'puppo'], axis=1)

# %%
#Replace doges without stage with floof
df1_clean.dog_stage.replace('', 'floof', inplace = True)

# %% [markdown]
# #### Test

# %%
df1_clean.head(50)
# Out:
#               tweet_id                              source  \
# 0   892420643555336193  http://twitter.com/download/iphone
# 1   892177421306343426  http://twitter.com/download/iphone
# 2   891815181378084864  http://twitter.com/download/iphone
# 3   891689557279858688  http://twitter.com/download/iphone
# 4   891327558926688256  http://twitter.com/download/iphone
# 5   891087950875897856  http://twitter.com/download/iphone
# 6   890971913173991426  http://twitter.com/download/iphone
# 7   890729181411237888  http://twitter.com/download/iphone
# 8   890609185150312448  http://twitter.com/download/iphone
# 9   890240255349198849  http://twitter.com/download/iphone
# 10  890006608113172480  http://twitter.com/download/iphone
# 11  889880896479866881  http://twitter.com/download/iphone
# 12  889665388333682689  http://twitter.com/download/iphone
# 13  889638837579907072  http://twitter.com/download/iphone
# 14  889531135344209921  http://twitter.com/download/iphone
# ...

# %% [markdown]
#  #### dog with stage of both doggo and pupper be a puppo from the dogtionary

# %%
#Replace doggopuppo with pupper

df1_clean.dog_stage.replace('doggopupper', 'puppo', inplace = True)

# %%
#check if the above query is correct, it should return no record
df1_clean.query('dog_stage == "doggopupper"')
# Out:
# Empty DataFrame
# Columns: [tweet_id, source, text, expanded_urls, rating_numerator, rating_denominator, name, tweet_date, dog_stage]
# Index: []

# %% [markdown]
# #### dog with stage of both puppo and doggo should be a puppo

# %%
#Replace doggopuppo with puppo
df1_clean.dog_stage.replace('doggopuppo', 'puppo', inplace = True)

# %%
#check if the above query is correct, it should return no record
df1_clean.query('dog_stage == "doggopuppo"')
# Out:
# Empty DataFrame
# Columns: [tweet_id, source, text, expanded_urls, rating_numerator, rating_denominator, name, tweet_date, dog_stage]
# Index: []

# %% [markdown]
# ### Issue #10:twitter_archive_enhanced(df1), df3 should be part of tweet_json.txt(df2)  dataframe

# %% [markdown]
# #### Define: Merge the 3 dataframes together into a single dataframe

# %% [markdown]
# #### Code

# %%
#merge df1_clean and df2_clean based on their ids
df2_clean = pd.merge(df2_clean, df1_clean, how="inner",
                            on= 'tweet_id')

# %%
df2_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog  \
# ...

# %%
#merge df1_clean and df3_clean based on their ids
df2_clean = pd.merge(df2_clean, df3_clean, how="inner",
                      on= 'tweet_id')

# %%
#Drop retweet_count from  df2_clean
df2_clean = df2_clean.drop('retweet_count', axis = 1)

# %%
df2_clean.shape
# Out:
# (1004, 21)

# %% [markdown]
# #### Test

# %%
df2_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 1  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 2  666050758794694657  https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 3  666055525042405380  https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 4  666058600524156928  https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
#
#    img_num                    p1   p1_conf  p1_dog                  p2  \
# 0        1               redbone  0.506826    True  miniature_pinscher
# 1        1   Rhodesian_ridgeback  0.408143    True             redbone
# 2        1  Bernese_mountain_dog  0.651137    True    English_springer
# 3        1                  chow  0.692517    True     Tibetan_mastiff
# 4        1      miniature_poodle  0.201493    True            komondor
#
#     p2_conf  p2_dog                           p3  ...  p3_dog  \
# ...

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
df2_clean.to_csv('twitter_archive_master.csv', index=False)

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('twitter_archive_master.csv')

# %%
dogStage = df.groupby('dog_stage')['rating_numerator'].mean()

# %%
NumberOfImage = df.groupby('img_num')['rating_numerator'].mean()

# %%
FavoriteCount = df.groupby('favorite_count')['rating_numerator'].mean()

# %% [markdown]
# ### Insights:
# 1. Favourite count determine if a particular dog stage will recieve more ratings
#
# 2. Dog stage have an influence on twee_ratings
#
# 3. The number of images in a tweet have influnce the tweet_ratings

# %% [markdown]
# ### Visualization

# %%
# Define a function to plot horizontal barcharts
def horizontalbarChart(Dataframe, x_label, y_label, title, size):
    Dataframe.plot.barh(figsize=size)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title, fontsize=14)
    plt.show()
# Define a function to plot Vertical barcharts
def verticalbarChart(Dataframe, x_label, y_label, title, size):
    Dataframe.plot.bar(figsize=size)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title, fontsize=14)
    plt.show()

# %%
verticalbarChart(dogStage,'Dog_Stage','Tweet Ratings','Mean of Tweet Rating vs Dog Stage', (12,8))

# %%
verticalbarChart(NumberOfImage, 'Number Of Image', 'Tweet Rating','Mean of Tweet Rating vs Number Of Image', (12,8))
